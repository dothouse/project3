# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # py 파일 만들기

# %%
# my_script.py 파일을 생성
# %%writefile my_script.py

def hello():
    print("Hello from the .py file!")

if __name__ == "__main__":
    hello()

# %%
# 기존 my_script.py 파일 편집
# %%writefile my_script.py

def hello():
    print("Hello again from the edited .py file!")

if __name__ == "__main__":
    hello()

# %% [markdown]
# # py 파일 편집

# %%
file_path = '/content/drive/MyDrive/project3/code/image_function/vram_reset.py'

# 파일 내용을 읽어옵니다.
with open(file_path, 'r') as file:
    print(file.read())
# Out:
# import gc
# from tensorflow.keras.backend import clear_session
#
# def reset_vram():
#     """Function to reset VRAM in Google Colab."""
#     clear_session()
#     gc.collect()

# %%
# 새 파일 내용을 작성합니다.
new_content = """
def hello():
    print("Hello from the edited .py file in Google Drive!")

if __name__ == "__main__":
    hello()
"""

# 파일 내용을 편집합니다.
with open(file_path, 'w') as file:
    file.write(new_content)
