# %% [markdown]
# # 주어진 Crop 영역을 새로운 이미지 파일로 만들기 위한 작업
#
# - crop이 없는 경우 기존 이미지 사용
# - crop이 있는 경우 crop image로 대체

# %% [markdown]
# ## data prepration

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

from tqdm import tqdm

import os
import shutil
import warnings
warnings.filterwarnings(action='ignore')

# %%
def load_image_path(dir):
    food_middle_list = sorted(os.listdir(dir))

    food_list = [] # 음식이름
    food_path_list = [] # 음식이름 경로

    for food_middle in food_middle_list:
        middle_path = os.path.join(dir,food_middle)
        food_name_list = os.listdir(middle_path)

        for food in food_name_list:
            path = os.path.join(middle_path,food)
            food_path_list.append(path)

            name = path.split('/')[-1]
            food_list.append(name)

    return food_list, food_path_list

# %%
data_dir = '/content/drive/MyDrive/project3/data/traindata/kfood'
food_list, food_path_list = load_image_path(data_dir)

print(len(food_list))
print(food_list)
print(food_path_list)
# Out:
# 99
# ['갈비구이', '갈치구이', '고등어구이', '곱창구이', '닭갈비', '장어구이', '조개구이', '떡갈비', '불고기', '삼겹살', '더덕구이', '조기구이', '황태구이', '훈제오리', '콩나물국', '계란국', '떡국_만두국', '시래기국', '무국', '북엇국', '미역국', '육개장', '과메기', '편육', '콩자반', '양념치킨', '피자', '후라이드치킨', '젓갈', '갓김치', '깍두기', '나박김치', '무생채', '배추김치', '부추김치', '열무김치', '백김치', '총각김치', '오이소박이', '파김치', '가지볶음', '고사리나물', '미역줄기볶음', '숙주나물', '시금치나물', '애호박볶음', '송편', '꿀떡', '경단', '만두', '장', '적', '장아찌', '전', '전골', '조림', '라면', '쫄면', '짬뽕', '물냉면', '짜장면', '비빔냉면', '수제비', '막국수', '잔치국수', '열무국수', '칼국수', '콩국수', '도토리묵', '콩나물무침', '꽈리고추무침', '도라지무침', '잡채', '홍어무침', '회무침', '김밥', '김치볶음밥', '누룽지', '알밥', '비빔밥', '잡곡밥', '새우볶음밥', '주먹밥', '유부초밥', '고추장진미채볶음', '라볶이', '두부김치', '감자채볶음', '떡볶이', '건새우볶음', '소세지볶음', '멸치볶음', '어묵볶음', '오징어채볶음', '제육볶음', '주꾸미볶음', '보쌈', '수정과', '식혜']
# ['/content/drive/MyDrive/project3/data/traindata/kfood/구이/갈비구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/갈치구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/고등어구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/곱창구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/닭갈비', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/장어구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/조개구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/떡갈비', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/불고기', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/삼겹살', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/더덕구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/조기구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/황태구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/훈제오리', '/content/drive/MyDrive/project3/data/traindata/kfood/국/콩나물국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/계란국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/떡국_만두국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/시래기국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/무국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/북엇국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/미역국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/육개장', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/과메기', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/편육', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/콩자반', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/양념치킨', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/피자', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/후라이드치킨', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/젓갈', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/갓김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/깍두기', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/나박김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/무생채', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/배추김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/부추김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/열무김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/백김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/총각김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/오이소박이', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/파김치', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/가지볶음', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/고사리나물', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/미역줄기볶음', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/숙주나물', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/시금치나물', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/애호박볶음', '/content/drive/MyDrive/project3/data/traindata/kfood/떡/송편', '/content/drive/MyDrive/project3/data/traindata/kfood/떡/꿀떡', '/content/drive/MyDrive/project3/data/traindata/kfood/떡/경단', '/content/drive/MyDrive/project3/data/traindata/kfood/만두/만두', '/content/drive/MyDrive/project3/data/traindata/kfood/만두/장', '/content/drive/MyDrive/project3/data/traindata/kfood/만두/적', '/content/drive/MyDrive/project3/data/traindata/kfood/만두/장아찌', '/content/drive/MyDrive/project3/data/traindata/kfood/만두/전', '/content/drive/MyDrive/project3/data/traindata/kfood/만두/전골', '/content/drive/MyDrive/project3/data/traindata/kfood/만두/조림', '/content/drive/MyDrive/project3/data/trainda ...

# %% [markdown]
# ## Create Boxed Images

# %%
def make_new_image(raw_image_path):
    crop_file_name = 'crop_area.properties'
    crop_file_path = os.path.join(raw_image_path, crop_file_name)

    boxed_image_path = raw_image_path.replace('kfood', 'check_boxed_image') # box 그린 파일만
    if not os.path.exists(boxed_image_path):
        os.makedirs(boxed_image_path)

    boxed_raw_image_path = raw_image_path.replace('kfood', 'train_image_box') # box그린 파일 + 안그린 파일
    if not os.path.exists(boxed_raw_image_path):
        os.makedirs(boxed_raw_image_path)

    crop_image_path = raw_image_path.replace('kfood', 'check_crop_image') # crop 파일만
    if not os.path.exists(crop_image_path):
        os.makedirs(crop_image_path)

    crop_raw_image_path = raw_image_path.replace('kfood', 'train_image_crop') # crop 파일 + non_crop 파일
    if not os.path.exists(crop_raw_image_path):
        os.makedirs(crop_raw_image_path)


    # 딕셔너리 초기화
    crop_areas = {}
    error_list = []
    change_keys = set()

    print(raw_image_path)
    # crop 부분 정리
    with open(crop_file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

        for line in lines:

            # 각 줄에서 = 을 기준으로 키-값 쌍 분리
            key, value = line.strip().split('=')
            # 값을 정수 리스트로 변환
            # 좌표값이 틀리게 저장된 경우 존재
            try:
                coordinates = list(map(int, value.split(',')))
            except:
                error_list.append(f"좌표값 오류 {key}: {value}")
                continue
            # 딕셔너리에 저장
            crop_areas[key] = coordinates

            # 이미지 파일 경로 - jpg, png, bmp 확장자 확인
            img_extensions = ['.jpg', '.jpeg', '.JPG', '.JEPG', '.png', '.PNG', '.bmp', '.BMP']
            image_path = None

            for ext in img_extensions:
                potential_path = os.path.join(raw_image_path, f"{key}{ext}")
                if os.path.exists(potential_path):
                    image_path = potential_path
                    break

            # 이미지 읽기
            if image_path is not None and os.path.isfile(image_path):

                # 처리된 파일들을 change_key set에 넣는다
                change_keys.add(key)
                # RGBA 형식의 파일들이 존재 - 알파 채널 포함하여 읽기
                image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)

                if image is not None:
                    x, y, w, h = coordinates

                    # Save Cropped image
                    ## Crop Box
                    crop_img = image[y:y+h, x:x+w]
                    ## Save - only crop
                    output_crop_image_path = os.path.join(crop_image_path, f"crop_{key}.jpg")
                    cv2.imwrite(output_crop_image_path, crop_img)
                    ## save - with non_crop
                    output_crop_image_path2 = os.path.join(crop_raw_image_path, f"{key}_crop.jpg")
                    cv2.imwrite(output_crop_image_path2, crop_img)


                    # Save Boxed image
                    ## Draw Box
                    boxed_image = cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 255), 2)
                    ## save - only boxed
                    output_box_image_path = os.path.join(boxed_image_path, f"box_{key}.jpg")
                    cv2.imwrite(output_box_image_path, boxed_image)
                    ## save - with non_boxed
                    output_box_image_path2 = os.path.join(boxed_raw_image_path, f"{key}_box.jpg")
                    cv2.imwrite(output_box_image_path2, crop_img)


                else :
                    error_list.append(f"Image can't read: {key}")
            else :
                error_list.append(f"Image not found: {key}")

        # change_key에 해당하지 않는 파일 복사
        # 즉, 변화가 없는
        for filename in os.listdir(raw_image_path):
            file_key = os.path.splitext(filename)[0]
            if file_key not in change_keys:
                src_path = os.path.join(raw_image_path, filename)

                # boxed
                dest_path = os.path.join(boxed_raw_image_path, filename)
                shutil.copy(src_path, dest_path)
                # cropped
                dest_path2 = os.path.join(crop_raw_image_path, filename)
                shutil.copy(src_path, dest_path2)

        # error list 출력
        print('\n')
        for error in error_list:
            print(error)
        print('------------------------')

# %%
for food_path in tqdm(food_path_list[1:2]):
    make_new_image(food_path)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# /content/drive/MyDrive/project3/data/traindata/kfood/구이/갈치구이
# 100%|██████████| 1/1 [02:50<00:00, 170.33s/it]
# Image can't read: Img_001_0286
# Image can't read: Img_001_0355
# ------------------------

# %%
data_dir = '/content/drive/MyDrive/project3/data/traindata/train_image_box'
food_list, food_path_list = load_image_path(data_dir)

print(len(food_list))
print(food_list)
print(food_path_list)
# Out:
# 1
# ['갈치구이']
# ['/content/drive/MyDrive/project3/data/traindata/train_image_box/구이/갈치구이']

# %%
def load_image_path(dir):
    food_middle_list = sorted(os.listdir(dir))
    food_list = []  # 음식 이름
    food_path_list = []  # 음식 이름 경로

    for food_middle in food_middle_list:
        middle_path = os.path.join(dir, food_middle)
        food_name_list = os.listdir(middle_path)

        for food in food_name_list:
            path = os.path.join(middle_path, food)
            food_path_list.append(path)
            name = path.split('/')[-1]
            food_list.append(name)

    return food_list, food_path_list

def get_all_image_files(dir):
    img_extensions = {'.jpg', '.jpeg', '.png', '.bmp'}
    image_files = []

    for root, _, files in os.walk(dir):
        for file in files:
            if any(file.lower().endswith(ext) for ext in img_extensions):
                image_files.append(os.path.join(root, file))

    return image_files

# %%
data_dir = '/content/drive/MyDrive/project3/data/traindata/train_image_crop'
len(get_all_image_files(data_dir))
# Out:
# 998
