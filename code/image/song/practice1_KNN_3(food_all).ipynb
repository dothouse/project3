# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 이미지 분류 연습 - 머신러닝(KNN)
#
# K-NN 알고리즘을 사용하여 이미지 분류하기
#
# K-NN 알고리즘은 무엇인가?
#
# 거리 기반 알고리즘

# %%
import pandas as pd
import numpy as np
from skimage.transform import resize
from skimage.io import imread

import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] =False

import os

# %%
datadir = '/content/drive/MyDrive/project3/data/traindata/kfood'

food_middle_list = os.listdir(datadir)
food_middle_list = sorted(food_middle_list)
food_middle_list[:5]
# Out:
# ['구이', '국', '기타', '김치', '나물']

# %%
food_list = [] # 음식이름
food_path_list = [] # 음식이름 경로

for food_middle in food_middle_list:
    middle_path = os.path.join(datadir,food_middle)
    food_name_list = os.listdir(middle_path)
    for food in food_name_list:
        path = os.path.join(middle_path,food)
        food_path_list.append(path)

        name = path.split('/')[-1]
        food_list.append(name)

print(len(food_list))
print(food_list)
print(food_path_list)
# Out:
# 150
# ['갈비구이', '갈치구이', '고등어구이', '곱창구이', '장어구이', '떡갈비', '더덕구이', '불고기', '조개구이', '삼겹살', '조기구이', '닭갈비', '훈제오리', '황태구이', '계란국', '떡국_만두국', '무국', '미역국', '시래기국', '콩나물국', '육개장', '북엇국', '젓갈', '양념치킨', '과메기', '콩자반', '편육', '피자', '후라이드치킨', '갓김치', '깍두기', '나박김치', '무생채', '배추김치', '백김치', '부추김치', '열무김치', '오이소박이', '파김치', '총각김치', '가지볶음', '시금치나물', '애호박볶음', '고사리나물', '숙주나물', '미역줄기볶음', '경단', '꿀떡', '송편', '만두', '라면', '막국수', '물냉면', '비빔냉면', '수제비', '열무국수', '콩국수', '짬뽕', '잔치국수', '칼국수', '짜장면', '쫄면', '꽈리고추무침', '도라지무침', '도토리묵', '잡채', '콩나물무침', '회무침', '홍어무침', '누룽지', '김밥', '김치볶음밥', '비빔밥', '새우볶음밥', '알밥', '유부초밥', '잡곡밥', '주먹밥', '감자채볶음', '건새우볶음', '소세지볶음', '떡볶이', '라볶이', '두부김치', '고추장진미채볶음', '멸치볶음', '어묵볶음', '오징어채볶음', '제육볶음', '주꾸미볶음', '보쌈', '식혜', '수정과', '양념게장', '간장게장', '깻잎장아찌', '떡꼬치', '감자전', '계란말이', '계란후라이', '김치전', '동그랑땡', '생선전', '호박전', '파전', '곱창전골', '갈치조림', '감자조림', '고등어조림', '꽁치조림', '두부조림', '땅콩조림', '메추리알장조림', '연근조림', '우엉조림', '장조림', '코다리조림', '전복죽', '호박죽', '김치찌개', '닭계장', '동태찌개', '된장찌개', '순두부찌개', '갈비찜', '계란찜', '김치찜', '순대', '수육', '꼬막찜', '닭볶음탕', '찜닭', '족발', '해물찜', '매운탕', '갈비탕', '곰탕_설렁탕', '감자탕', '삼계탕', '추어탕', '고추튀김', '새우튀김', '오징어튀김', '약식', '한과', '약과', '멍게', '산낙지', '물회', '육회']
# ['/content/drive/MyDrive/project3/data/traindata/kfood/구이/갈비구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/갈치구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/고등어구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/곱창구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/장어구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/떡갈비', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/더덕구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/불고기', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/조개구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/삼겹살', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/조기구이', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/닭갈비', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/훈제오리', '/content/drive/MyDrive/project3/data/traindata/kfood/구이/황태구이', '/content/drive/MyDrive/project3/data/traindata/kfood/국/계란국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/떡국_만두국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/무국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/미역국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/시래기국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/콩나물국', '/content/drive/MyDrive/project3/data/traindata/kfood/국/육개장', '/content/drive/MyDrive/project3/data/traindata/kfood/국/북엇국', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/젓갈', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/양념치킨', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/과메기', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/콩자반', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/편육', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/피자', '/content/drive/MyDrive/project3/data/traindata/kfood/기타/후라이드치킨', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/갓김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/깍두기', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/나박김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/무생채', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/배추김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/백김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/부추김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/열무김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/오이소박이', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/파김치', '/content/drive/MyDrive/project3/data/traindata/kfood/김치/총각김치', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/가지볶음', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/시금치나물', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/애호박볶음', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/고사리나물', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/숙주나물', '/content/drive/MyDrive/project3/data/traindata/kfood/나물/미역줄기볶음', '/content/drive/MyDrive/project3/data/traindata/kfood/떡/경단', '/content/drive/MyDrive/project3/data/traindata/kfood/떡/꿀떡', '/content/drive/MyDrive/project3/data/traindata/kfood/떡/송편', '/content/drive/MyDrive/project3/data/traindata/kfood/만두/만두', '/content/drive/MyDrive/project3/data/traindata/kfood/면/라면', '/content/drive/MyDrive/project3/data/traindata/kfood/면/막국수', '/content/drive/MyDrive/project3/data/traindata/kfood/면/물냉면', '/content/drive/MyDrive/project3/data/traindata/kfood/면/비빔냉면', '/content/drive/MyDrive/project3/data/traindata/kfood/면/수제비', '/content/drive/MyDrive/project3/data/traindata/kfood/면/열무국수', '/content/drive/MyDrive/project3/da ...

# %%
target = []
images = []   # In matrix format
flat_data = []  # In vector format

datadir = '/content/drive/MyDrive/project3/data/traindata/kfood'
# food_path_list = food_path_list[:5]

for idx, food_path in enumerate(food_path_list):
    food = food_path.split('/')[-1]

    for img in os.listdir(food_path):
        img_path = os.path.join(food_path,img)
        img_type = img_path.split('.')[-1]
        if img_type == 'jpg':
            img_matrix = imread(img_path)
            img_resized = resize(img_matrix,(150,150,3))
            flat_data.append(img_resized.flatten())
            images.append(img_resized)
            target.append(food)

# %%
import pandas as pd
df=pd.DataFrame(flat_data)
df['Target']=target

# %%
df.shape

# %%
# Display of the number of images of each Food type
plt.bar(df['Target'].unique(),df['Target'].value_counts())
plt.title('Food vs Quantity')
plt.xlabel('Food Name')
plt.ylabel('No. of Foods')
plt.show()

# %%
# Input and Output
x=df.iloc[:,0:67500].values
y=df.iloc[:,67500].values

# %% [markdown]
# 3) Classification of images using KNN Classification Algorithm

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
# k=np.arange(1,160)
k = [i if i != 0 else 1 for i in range(0, 160, 5)]
param={'n_neighbors':k}
model=KNeighborsClassifier()
model_grid=GridSearchCV(model,param)
model_grid.fit(x,y)

# %%
# Best K nearest neighbor
model_grid.best_params_

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
best_k = model_grid.best_params_['n_neighbors']
model = KNeighborsClassifier(n_neighbors=best_k, metric='euclidean')
model.fit(x_train,y_train)

# %%
# Predicted output
y_pred = model.predict(x_test)
y_pred

# %%
# Actual output
y_test

# %%
# Evaluation of the model
from sklearn.metrics import accuracy_score
print("The accuracy of the model is ",accuracy_score(y_pred,y_test)*100,"%")

# %% [markdown]
# # 4) Confusion matrix and Classification report

# %%
# Confusion matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_pred,y_test)
cm

# %%
# Classification report
from sklearn import metrics
metrics.classification_report(y_test,y_pred)

# %% [markdown]
# # 5) Prediction for new image

# %%
# # Resizing and flattening new image 1
# img1=imread('/content/drive/My Drive/images/New prediction images/plantsguru-flowering-plants-rose-red-800x800.jpg')
# img1_resize = resize(img1,(150,150,3))
# img1_flatten = img1_resize.flatten()

# %%
# img1_pred = model.predict([img1_flatten])
# img1_pred

# %%
# plt.imshow(img1)
