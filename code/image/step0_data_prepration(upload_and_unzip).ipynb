# %% [markdown]
# # 데이터 준비
#
# ### Ai-hub - 한국 이미지(음식)
# >https://www.aihub.or.kr/aihubdata/data/view.do?currMenu=&topMenu=&aihubDataSe=data&dataSetSn=79
#
# - 음식종류 : 150종
# - 사진 수 : 150종 * 1000장 -> 150,000장

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile
import shutil

# %%
from google.colab import files
uploaded = files.upload()

# %%
# 압축 해제 하기
# %cd /content/drive/MyDrive/project3/data/traindata/food_image/
# !unzip -qq "/content/drive/MyDrive/project3/data/traindata/food_image/kfood.zip"
# Out:
# /content/drive/.shortcut-targets-by-id/1gdU-KuXDUU7v2o8X7TdV0JgGiz603mCc/project3/data/traindata/food_image

# %%
# %cd /content/drive/MyDrive/project3/data/traindata/food_image/
zip_files = os.listdir()
zip_files
# Out:
# /content/drive/.shortcut-targets-by-id/1gdU-KuXDUU7v2o8X7TdV0JgGiz603mCc/project3/data/traindata/food_image
# ['회.zip',
#  '해물.zip',
#  '한과.zip',
#  '튀김.zip',
#  '탕.zip',
#  '찌개.zip',
#  '죽.zip',
#  '찜.zip',
#  '전골.zip',
#  '조림.zip',
#  '적.zip',
#  '장아찌.zip',
#  '전.zip',
#  '음청류.zip',
#  '장.zip',
#  '쌈.zip',
#  '밥.zip',
#  '볶음.zip',
#  '무침.zip',
#  '만두.zip',
#  '떡.zip',
#  '나물.zip',
#  '면.zip',
#  '기타.zip',
#  '김치.zip',
#  '국.zip',
#  '구이.zip',
#  'kfood.zip']

# %%
import zipfile

zip_files = [f for f in zip_files if f.endswith('.zip') and f != 'kfood.zip']

for zip_file in zip_files:
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall()

# %%
zip_dir = '/content/drive/MyDrive/project3/data/traindata/food_image/'
for zip_file in zip_files:
    shutil.move(zip_file, os.path.join(zip_dir, zip_file))

# %%
# 데이터 경로 지정

datadir = '/content/drive/MyDrive/project3/data/traindata/kfood2'

food_middle_list = sorted(os.listdir(datadir))
food_middle_list[:5]
# Out:
# ['구이', '국', '기타', '김치', '나물']

# %%
#  데이터 경로 만들기

food_list = [] # 음식이름
food_path_list = [] # 음식이름 경로

for food_middle in food_middle_list:
    middle_path = os.path.join(datadir,food_middle)
    food_name_list = os.listdir(middle_path)

    for food in food_name_list:
        path = os.path.join(middle_path,food)
        food_path_list.append(path)

        name = path.split('/')[-1]
        food_list.append(name)

print(len(food_list))
print(food_list)
print(food_path_list)
# Out:
# 153
# ...
