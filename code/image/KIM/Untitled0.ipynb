# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Generic Packages
import numpy as np
import os
import pandas as pd

#Machine Learning Library
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle

#Plotting Libraries
import seaborn as sn; sn.set(font_scale=1.4)
import matplotlib.pyplot as plt

#openCV
import cv2

#Tensor Flow
import tensorflow as tf

#Display Progress
from tqdm import tqdm

from skimage.transform import resize

# %%
categories = []
rootdir = '/content/drive/MyDrive/project3/data/traindata/kfood/무침'
for file in os.listdir(rootdir):
    d = os.path.join(rootdir, file)
    if os.path.isdir(d):
      categories.append(file)

categories_label = {category:i for i, category in enumerate(categories)} # 카테고리랑 숫자로 바꾼 값 dict형태로 만들기

# %%
categories_label
# Out:
# {'도토리묵': 0,
#  '콩나물무침': 1,
#  '꽈리고추무침': 2,
#  '도라지무침': 3,
#  '잡채': 4,
#  '홍어무침': 5,
#  '회무침': 6}

# %%
def load_data():

  rootdir = '/content/drive/MyDrive/project3/data/traindata/kfood/무침'
  images = []
  labels = []
# Iterate through each folder corresponding to a category
  for category in categories:
    path = os.path.join(rootdir,category)
    label = categories_label[category]

# Iterate through each image in our folder
    for img in tqdm(os.listdir(path)):
      try:
        # Get the path name of the image
        img_path = os.path.join(path, img)

        # Open and resize the img
        image = cv2.imread(img_path)
        #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image,(224, 224))

        # Append the image and its corresponding label to the output
        images.append(image)
        labels.append(label)
      except Exception as someReadingError:
        pass

  return images , labels

# %%
#Loading Data (Training & Test Dataset)
Images, Labels = load_data()
# Out:
#   1%|          | 10/1005 [00:15<25:54,  1.56s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-1cd74c26cf83> in <cell line: 2>()
#       1 #Loading Data (Training & Test Dataset)
# ----> 2 Images, Labels = load_data()
#
# <ipython-input-11-3757bfbc1d6c> in load_data()
#      16
#      17         # Open and resize the img
# ---> 18         image = cv2.imread(img_path)
#      19         #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      20         image = cv2.resize(image,(224, 224))
#
# KeyboardInterrupt:

# %%
X=np.array(Images)
Y=np.array(Labels)
