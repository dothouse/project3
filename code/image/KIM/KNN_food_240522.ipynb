# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. KNN을 이용하여 이미지 분류

# %% [markdown]
# ### 1) Pre-processing of data

# %%
import numpy as np
from skimage.transform import resize
from skimage.io import imread
import matplotlib.pyplot as plt
import os

# %%
import os
files = []
rootdir = '/content/drive/MyDrive/project3/data/traindata/kfood2/'
for file in os.listdir(rootdir):
    d = os.path.join(rootdir, file)
    if os.path.isdir(d):
        files.append(file)

# %%
files
# Out:
# ['탕',
#  '튀김',
#  '한과',
#  '해물',
#  '회',
#  '구이',
#  '국',
#  '기타',
#  '김치',
#  '나물',
#  '만두',
#  '무침',
#  '떡',
#  '면',
#  '밥',
#  '볶음',
#  '쌈',
#  '음청류',
#  '장',
#  '죽',
#  '찌개',
#  '장아찌',
#  '조림',
#  '적',
#  '전골',
#  '전',
#  '찜']

# %%
categories = []
rootdir = '/content/drive/MyDrive/project3/data/traindata/kfood2/'
for file in os.listdir(rootdir):
    d = os.path.join(rootdir, file)
    if os.path.isdir(d):
      for category in os.listdir(d):
        b = os.path.join(d)
        if os.path.isdir(b):
          categories.append(category)

# %%
categories
# Out:
# ['매운탕',
#  '갈비탕',
#  '곰탕_설렁탕',
#  '감자탕',
#  '삼계탕',
#  '추어탕',
#  '고추튀김',
#  '새우튀김',
#  '오징어튀김',
#  '약식',
#  '한과',
#  '약과',
#  '멍게',
#  '산낙지',
#  '물회',
#  '육회',
#  '갈비구이',
#  '갈치구이',
#  '고등어구이',
#  '곱창구이',
#  '장어구이',
#  '떡갈비',
#  '더덕구이',
#  '불고기',
#  '조개구이',
#  '삼겹살',
#  '조기구이',
#  '닭갈비',
#  '훈제오리',
#  '황태구이',
#  '계란국',
#  '떡국_만두국',
#  '무국',
#  '미역국',
#  '시래기국',
#  '콩나물국',
#  '육개장',
#  '북엇국',
#  '젓갈',
#  '양념치킨',
#  '과메기',
#  '콩자반',
#  '편육',
#  '피자',
#  '후라이드치킨',
#  '갓김치',
#  '깍두기',
#  '나박김치',
#  '무생채',
#  '배추김치',
#  '백김치',
#  '부추김치',
#  '열무김치',
#  '오이소박이',
#  '파김치',
#  '총각김치',
#  '가지볶음',
#  '시금치나물',
#  '애호박볶음',
#  '고사리나물',
#  '숙주나물',
#  '미역줄기볶음',
#  '만두',
#  '꽈리고추무침',
#  '도라지무침',
#  '도토리묵',
#  '잡채',
#  '콩나물무침',
#  '회무침',
#  '홍어무침',
#  '경단',
#  '꿀떡',
#  '송편',
#  '라면',
#  '막국수',
#  '물냉면',
#  '비빔냉면',
#  '수제비',
#  '열무국수',
#  '콩국수',
#  '짬뽕',
#  '잔치국수',
#  '칼국수',
#  '짜장면',
#  '쫄면',
#  '누룽지',
#  '김밥',
#  '김치볶음밥',
#  '비빔밥',
#  '새우볶음밥',
#  '알밥',
#  '유부초밥',
#  '잡곡밥',
#  '주먹밥',
#  '감자채볶음',
#  '건새우볶음',
#  '소세지볶음',
#  '떡볶이',
#  '라볶이',
#  '두부김치',
#  '고추장진미채볶음',
#  '멸치볶음',
#  '어묵볶음',
#  '오징어채볶음',
#  '제육볶음',
#  '주꾸미볶음',
#  '보쌈',
#  '식혜',
#  '수정과',
#  '양념게장',
#  '간장게장',
#  '전복죽',
#  '호박죽',
#  '김치찌개',
#  '닭계장',
#  '동태찌개',
#  '된장찌개',
#  '순두부찌개',
#  '깻잎장아찌',
#  '갈치조림',
#  '감자조림',
#  '고등어조림',
#  '꽁치조림',
#  '두부조림',
#  '땅콩조림',
#  '메추리알장조림',
#  '연근조림',
#  '우엉조림',
#  '장조림',
#  '코다리조림',
#  '떡꼬치',
#  '곱창전골',
#  '감자전',
#  '계란말이',
#  '계란후라이',
#  '김치전',
#  '동그랑땡',
#  '생선전',
#  '호박전',
#  '파전',
#  '갈비찜',
#  '계란찜',
#  '김치찜',
#  '순대',
#  '수육',
#  '꼬막찜',
#  '닭볶음탕',
#  '찜닭',
#  '족발',
#  '해물찜']

# %%
rootdir = '/content/drive/MyDrive/project3/data/traindata/kfood2/'
for file in os.listdir(rootdir):
    d = os.path.join(rootdir, file)
    print(d)
# Out:
# /content/drive/MyDrive/project3/data/traindata/kfood2/탕
# /content/drive/MyDrive/project3/data/traindata/kfood2/튀김
# /content/drive/MyDrive/project3/data/traindata/kfood2/한과
# /content/drive/MyDrive/project3/data/traindata/kfood2/해물
# /content/drive/MyDrive/project3/data/traindata/kfood2/회
# /content/drive/MyDrive/project3/data/traindata/kfood2/구이
# /content/drive/MyDrive/project3/data/traindata/kfood2/국
# /content/drive/MyDrive/project3/data/traindata/kfood2/기타
# /content/drive/MyDrive/project3/data/traindata/kfood2/김치
# /content/drive/MyDrive/project3/data/traindata/kfood2/나물
# /content/drive/MyDrive/project3/data/traindata/kfood2/만두
# /content/drive/MyDrive/project3/data/traindata/kfood2/무침
# /content/drive/MyDrive/project3/data/traindata/kfood2/떡
# /content/drive/MyDrive/project3/data/traindata/kfood2/면
# /content/drive/MyDrive/project3/data/traindata/kfood2/밥
# /content/drive/MyDrive/project3/data/traindata/kfood2/볶음
# /content/drive/MyDrive/project3/data/traindata/kfood2/쌈
# /content/drive/MyDrive/project3/data/traindata/kfood2/음청류
# /content/drive/MyDrive/project3/data/traindata/kfood2/장
# /content/drive/MyDrive/project3/data/traindata/kfood2/죽
# /content/drive/MyDrive/project3/data/traindata/kfood2/찌개
# /content/drive/MyDrive/project3/data/traindata/kfood2/장아찌
# /content/drive/MyDrive/project3/data/traindata/kfood2/조림
# /content/drive/MyDrive/project3/data/traindata/kfood2/적
# /content/drive/MyDrive/project3/data/traindata/kfood2/전골
# /content/drive/MyDrive/project3/data/traindata/kfood2/전
# /content/drive/MyDrive/project3/data/traindata/kfood2/찜

# %%
target = []
images = []   # In matrix format
flat_data = []  # In vector format

rootdir = '/content/drive/MyDrive/project3/data/traindata/kfood2/'
for file in os.listdir(rootdir):
    datadir = os.path.join(rootdir, file)
    for category in os.listdir(datadir):
      categorypath = os.path.join(datadir,category)
      for img in os.listdir(categorypath):
        try:
          img_matrix=imread(os.path.join(categorypath,img))
          img_resized=resize(img_matrix,(150,150,3))
          flat_data.append(img_resized.flatten())
          images.append(img_resized)
          target.append(category)
        except Exception as someReadingError:
          print(someReadingError)
# Out:
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/매운탕/crop_area.properties`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/매운탕/org_url.csv`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/갈비탕/crop_area.properties`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/갈비탕/org_url.csv`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/곰탕_설렁탕/crop_area.properties`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/곰탕_설렁탕/org_url.csv`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/감자탕/crop_area.properties`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/감자탕/org_url.csv`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/삼계탕/crop_area.properties`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/삼계탕/org_url.csv`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/추어탕/crop_area.properties`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/탕/추어탕/org_url.csv`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/튀김/고추튀김/crop_area.properties`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/튀김/고추튀김/org_url.csv`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/튀김/새우튀김/crop_area.properties`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/튀김/새우튀김/org_url.csv`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/튀김/오징어튀김/crop_area.properties`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/튀김/오징어튀김/org_url.csv`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/한과/약식/crop_area.properties`` with iomode `ri`.
# Could not find a backend to open `/content/drive/MyDrive/project3/data/traindata/kfood2/한과/약식/org_url.csv`` with iomode `ri`.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-00d2aee63bec> in <cell line: 6>()
#      11         try:
#      12           img_matrix=imread(os.path.join(categorypath,img))
# ---> 13           img_resized=resize(img_matrix,(150,150,3))
#      14           flat_data.append(img_resized.flatten())
#      15           images.append(img_resized)
#
# /usr/local/lib/python3.10/dist-packages/skimage/transform/_warps.py in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     163
#     164     # Save input value range for clip
# --> 165     img_bounds = np.array([image.min(), image.max()]) if clip else None
#     166
#     167     # Translate modes used by np.pad to those used by scipy.ndimage
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      46
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
import pandas as pd
df=pd.DataFrame(flat_data)
df['Target']=target
df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.779273  0.743979  0.724371  0.803309  0.768015  0.747627  0.826620
# 1     0.255497  0.231979  0.179572  0.255702  0.236790  0.192165  0.281069
# 2     0.945734  0.951720  0.958860  0.949075  0.952476  0.960296  0.953358
# 3     0.473038  0.488299  0.384241  0.508168  0.539718  0.398592  0.501164
# 4     1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 5995  0.857802  0.806821  0.744076  0.826115  0.775135  0.712390  0.825293
# 5996  0.098355  0.057551  0.047463  0.094980  0.052136  0.036518  0.097062
# 5997  0.944563  0.944563  0.944563  0.963802  0.963802  0.963802  0.965425
# 5998  0.056231  0.057469  0.056659  0.063380  0.066327  0.064744  0.057535
# 5999  0.860643  0.808430  0.695724  0.858843  0.806629  0.696839  0.856361
#
#              7         8         9  ...     67491     67492     67493  \
# 0     0.791326  0.764655  0.850466  ...  0.894645  0.859863  0.824666
# 1     0.265999  0.230708  0.287800  ...  0.971307  0.969944  0.976982
# 2     0.955776  0.963421  0.956558  ...  0.730108  0.668643  0.595031
# 3     0.517633  0.401449  0.445922  ...  0.551398  0.399579  0.150289
# 4     1.000000  1.000000  1.000000  ...  0.815729  0.799650  0.693973
# ...        ...       ...       ...  ...       ...       ...       ...
# 5995  0.774312  0.711567  0.822567  ...  0.831430  0.768719  0.705911
# 5996  0.052810  0.043561  0.099191  ...  0.134258  0.104420  0.086098
# 5997  0.965425  0.965425  0.965464  ...  0.965463  0.965463  0.965461
# 5998  0.063542  0.060434  0.058902  ...  0.017016  0.021319  0.012290
# 5999  0.806746  0.702761  0.855100  ...  0.690482  0.597354  0.503793
#
#          67494     67495     67496     67497     67498     67499  Target
# 0     0.877365  0.845286  0.820157  0.860249  0.832587  0.807285    가지볶음
# 1     0.992779  0.992130  0.997490  0.997639  0.997636  0.997718    가지볶음
# 2     0.689164  0.614487  0.545167  0.704215  0.641705  0.552324    가지볶음
# 3     0.579464  0.427276  0.142668  0.436141  0.297186  0.136315    가지볶음
# 4     0.786464  0.770775  0.666418  0.768171  0.752482  0.648388    가지볶음
# ...        ...       ...       ...       ...       ...       ...     ...
# 5995  0.830025  0.769252  0.702073  0.853222  0.793515  0.723564   애호박볶음
# 5996  0.127811  0.102540  0.092960  0.141855  0.107455  0.098501   애호박볶음
# 5997  0.965369  0.965369  0.965368  0.947994  0.947995  0.947994   애호박볶음
# 5998  0.014011  0.015195  0.007619  0.009600  0.009604  0.006224   애호박볶음
# 5999  0.729772  0.659336  0.594913  0.769782  0.714088  0.672411   애호박볶음
#
# [6000 rows x 67501 columns]

# %%
# Input and Output
x=df.iloc[:,0:67500].values
y=df.iloc[:,67500].values

# %% [markdown]
# ### 3) Classification of images using KNN Classification Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
model = KNeighborsClassifier(n_neighbors=16,metric='euclidean')
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=16)

# %%
# Predicted output
y_pred = model.predict(x_test)
y_pred
# Out:
# array(['고사리나물', '고사리나물', '숙주나물', ..., '가지볶음', '고사리나물', '고사리나물'],
#       dtype=object)

# %%
# Actual output
y_test
# Out:
# array(['시금치나물', '미역줄기볶음', '애호박볶음', ..., '고사리나물', '시금치나물', '고사리나물'],
#       dtype=object)

# %%
# Evaluation of the model
from sklearn.metrics import accuracy_score
print("The accuracy of the model is ",accuracy_score(y_pred,y_test)*100,"%")
# Out:
# The accuracy of the model is  30.266666666666666 %

# %% [markdown]
# ### 4) Confusion Matrix and Classification report

# %%
# Confusion matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_pred,y_test)
cm
# Out:
# array([[ 20,  16,   6,   1,  15,   2],
#        [ 33,  75,  31,   1,  61,   4],
#        [ 45,  31,  52,   9,  64,  16],
#        [137, 112, 131, 238,  73, 195],
#        [  2,   8,  12,   0,  48,   0],
#        [  8,   7,   6,   4,  16,  21]])

# %%
# Classification report
from sklearn import metrics
metrics.classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n        가지볶음       0.33      0.08      0.13       245\n       고사리나물       0.37      0.30      0.33       249\n      미역줄기볶음       0.24      0.22      0.23       238\n        숙주나물       0.27      0.94      0.42       253\n       시금치나물       0.69      0.17      0.28       277\n       애호박볶음       0.34      0.09      0.14       238\n\n    accuracy                           0.30      1500\n   macro avg       0.37      0.30      0.25      1500\nweighted avg       0.38      0.30      0.26      1500\n'
