# %% [markdown]
# # crop 된 이미지를 유사한 특성이 가진 1:1 크기의 파일로 변경
#
# - gray 스케일로 할지 안할지...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

from tqdm import tqdm

import os
import warnings
warnings.filterwarnings(action='ignore')

# %%
csv_path = '/content/drive/MyDrive/project3/data/traindata/read_file'

csv_files = os.listdir(csv_path)

# Filter out the CSV files
csv_files = [file for file in csv_files if file.endswith('.csv')]

# Initialize an empty list to hold the dataframes
temp = []

# Read each CSV file and append to the list
for csv_file in csv_files[50:51]:
    file_path = os.path.join(csv_path, csv_file)
    df = pd.read_csv(file_path)
    temp.append(df)

# %%
# Concatenate all dataframes
df = pd.concat(temp, ignore_index=True)
df = df[ (df['type'] == 'crop')]
df.reset_index(drop=True, inplace=True)
df['file_path'][0]
# Out:
#                                             file_path  type
# 0   /content/drive/MyDrive/project3/data/traindata...  crop
# 1   /content/drive/MyDrive/project3/data/traindata...  crop
# 2   /content/drive/MyDrive/project3/data/traindata...  crop
# 3   /content/drive/MyDrive/project3/data/traindata...  crop
# 4   /content/drive/MyDrive/project3/data/traindata...  crop
# 5   /content/drive/MyDrive/project3/data/traindata...  crop
# 6   /content/drive/MyDrive/project3/data/traindata...  crop
# 7   /content/drive/MyDrive/project3/data/traindata...  crop
# 8   /content/drive/MyDrive/project3/data/traindata...  crop
# 9   /content/drive/MyDrive/project3/data/traindata...  crop
# 10  /content/drive/MyDrive/project3/data/traindata...  crop
# 11  /content/drive/MyDrive/project3/data/traindata...  crop
# 12  /content/drive/MyDrive/project3/data/traindata...  crop
# 13  /content/drive/MyDrive/project3/data/traindata...  crop
# 14  /content/drive/MyDrive/project3/data/traindata...  crop
# 15  /content/drive/MyDrive/project3/data/traindata...  crop
# 16  /content/drive/MyDrive/project3/data/traindata...  crop
# 17  /content/drive/MyDrive/project3/data/traindata...  crop
# 18  /content/drive/MyDrive/project3/data/traindata...  crop
# 19  /content/drive/MyDrive/project3/data/traindata...  crop
# 20  /content/drive/MyDrive/project3/data/traindata...  crop
# 21  /content/drive/MyDrive/project3/data/traindata...  crop
# 22  /content/drive/MyDrive/project3/data/traindata...  crop
# 23  /content/drive/MyDrive/project3/data/traindata...  crop
# 24  /content/drive/MyDrive/project3/data/traindata...  crop
# 25  /content/drive/MyDrive/project3/data/traindata...  crop
# 26  /content/drive/MyDrive/project3/data/traindata...  crop
# 27  /content/drive/MyDrive/project3/data/traindata...  crop
# 28  /content/drive/MyDrive/project3/data/traindata...  crop
# 29  /content/drive/MyDrive/project3/data/traindata...  crop
# 30  /content/drive/MyDrive/project3/data/traindata...  crop
# 31  /content/drive/MyDrive/project3/data/traindata...  crop
# 32  /content/drive/MyDrive/project3/data/traindata...  crop
# 33  /content/drive/MyDrive/project3/data/traindata...  crop
# 34  /content/drive/MyDrive/project3/data/traindata...  crop
# 35  /content/drive/MyDrive/project3/data/traindata...  crop
# 36  /content/drive/MyDrive/project3/data/traindata...  crop
# 37  /content/drive/MyDrive/project3/data/traindata...  crop
# 38  /content/drive/MyDrive/project3/data/traindata...  crop
# 39  /content/drive/MyDrive/project3/data/traindata...  crop
# 40  /content/drive/MyDrive/project3/data/traindata...  crop
# 41  /content/drive/MyDrive/project3/data/traindata...  crop
# 42  /content/drive/MyDrive/project3/data/traindata...  crop
# 43  /content/drive/MyDrive/project3/data/traindata...  crop
# 44  /content/drive/MyDrive/project3/data/traindata...  crop
# 45  /content/drive/MyDrive/project3/data/traindata...  crop
# 46  /content/drive/MyDrive/project3/data/traindata...  crop
# 47  /content/drive/MyDrive/project3/data/traindata...  crop
# 48  /content/drive/MyDrive/project3/data/traindata...  crop
# 49  /content/drive/MyDrive/project3/data/traindata...  crop
# 50  /content/drive/MyDrive/project3/data/traindata...  crop
# 51  /content/drive/MyDrive/project3/data/traindata...  crop
# 52  /content/drive/MyDrive/project3/data/traindata...  crop

# %% [markdown]
# ## 그림을 정사각형으로 바꾸고자 한다.
# 1. 1:1형태의 patch를 만든다.
#     - 지금은 width, height 중 짧은 축
#     - (width, height 중 짧은 축을 기준으로 20pixel 작은)
# 2. patch를 x축 / y축으로 20씩 이동시켜서 histgram을 그리고
# 3. 원본의 histogram과 유사한 patch를 선택
# 4. 이를 새로운 이미지로 저장
#     - 컬러 / gray 2가지 방식으로 patch를 선택하고,
#     - 두 경우 다 저장

# %%
# histogram 그리기
def calculate_histogram(image):
    # Gray Scale 일떄
    if len(image.shape) == 2:
        histogram = cv2.calcHist([image], # 이미지
                                 [0], # 사용될 채널
                                 None, # 마스크
                                 [256], #bins
                                 [0, 256]) #각 채널의 최소값 / 최대값
    else:  # 컬러 이미지
        histogram = cv2.calcHist([image],
                                 [0, 1, 2],
                                 None,
                                 [256, 256, 256],
                                 [0, 256, 0, 256, 0, 256])

    # 히스토그램 정규화
    cv2.normalize(histogram, histogram)
    return histogram


# 원본과 가장 비슷한 hist를 갖는 그림을 선정
def find_best_match(image, target_hist, patch_size):

    # 가장 비슷한 사이즈를 정하기 위한 준비
    min_diff = float('inf')
    best_x, best_y = 0, 0

    # 이미지 크기
    # Gray Scale 일떄
    if len(image.shape) == 2:
        height, width = image.shape
    # 컬러 이미지
    else:
        height, width, _ = image.shape
    # patch의 위치를 20씩 이동시키며 비교
    for y in range(0, height - patch_size, 20):
        for x in range(0, width - patch_size, 20):
            patch = image[y:y + patch_size, x:x + patch_size]
            patch_hist = calculate_histogram(patch)
            diff = cv2.compareHist(target_hist, patch_hist, cv2.HISTCMP_BHATTACHARYYA)
            if diff < min_diff:
                min_diff = diff
                best_x, best_y = x, y

    return best_x, best_y

def extract_best_patch(image):

    image_size_adj = 20

    # gray로 판별하는 방법
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    height_g, width_g = image_gray.shape
    patch_size_g = min(height_g - image_size_adj, width_g - image_size_adj)  # 1:1 비율의 패치 크기 결정(원본보다 20 작게)
    target_hist_g = calculate_histogram(image_gray)

    best_x_g, best_y_g = find_best_match(image_gray, target_hist_g, patch_size_g)
    best_patch_gray = image[best_y_g:best_y_g + patch_size_g, best_x_g:best_x_g + patch_size_g]


    # color로 판별
    height, width, _ = image.shape

    patch_size = min(height -image_size_adj, width - image_size_adj)  # 1:1 비율의 패치 크기 결정(원본보다 20 작게)
    target_hist = calculate_histogram(image)  # 원본 이미지의 히스토그램 계산

    best_x, best_y = find_best_match(image, target_hist, patch_size)
    best_patch_color = image[best_y:best_y + patch_size, best_x:best_x + patch_size]

    return best_patch_gray, best_patch_color

# %%
pic_num = 25

test_image_path = df.iloc[15]['file_path']
test_image = cv2.imread(test_image_path)

# 원본
print('원본')
cv2_imshow(test_image)
# gray 이미지로 선택하기
print('gray 이미지로 선택')
cv2_imshow(extract_best_patch(test_image)[0])
# 컬러 이미지로 선택하기
print('컬러 이미지로 선택')
cv2_imshow(extract_best_patch(test_image)[1])
# Out:
# 원본
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-921686f5e816> in <cell line: 8>()
#       6 # 원본
#       7 print('원본')
# ----> 8 cv2_imshow(test_image)
#       9 # gray 이미지로 선택하기
#      10 print('gray 이미지로 선택')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
test_image_path
# Out:
# '/content/drive/MyDrive/project3/data/traindata/crop_image/밥/유부초밥/Img_075_0057_crop.jpg'

# %%
# 최선의 그림을 찾아서 저장하기
def select_best_patch_image(image_path):

    # 디렉토리 생성
    color_image_path = image_path.replace('raw_image', 'selected_image_by_color_hist').replace('Img', 'select_color')
    os.makedirs(os.path.dirname(color_image_path), exist_ok=True)

    gray_image_path = image_path.replace('raw_image', 'selected_image_by_gray_hist').replace('Img', 'select_gray')
    os.makedirs(os.path.dirname(gray_image_path), exist_ok=True)


    img = cv2.imread(image_path)
    if img is not None:

        # extract_best_patch(img[0]) -> gray hist로 선택
        # gray_select 만들기
        best_patch_gray = extract_best_patch(img)[0]
        # 저장하기
        cv2.imwrite(gray_image_path, best_patch_gray)

        # extract_best_patch(img[1]) -> color hist로 선택
        # color_select 만들기
        best_patch_color = extract_best_patch(img)[1]
        cv2.imwrite(color_image_path, best_patch_color)

# %%
for file_path in tqdm(df['file_path']):
    select_best_patch_image(file_path)
# Out:
# 100%|██████████| 988/988 [22:32<00:00,  1.37s/it]
