# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/project3
# Out:
# /content/drive/MyDrive/project3

# %%
# !git config --global user.email 'dothouse@naver.com'
# !git config --global user.name 'dothouse'

# %%
# !git add .
# !git commit -m "day(0528)_1 commit"
# !git push origin master
# Out:
# [master 52abf58] day(0528)_1 commit
#  11 files changed, 8 insertions(+), 3 deletions(-)
#  create mode 100644 code/image/KIM/Untitled1.ipynb
#  delete mode 100644 code/image/Untitled
#  create mode 100644 code/image/prep2_create_new_dataset.ipynb
#  delete mode 100644 "code/image/prep2_df\341\204\213\341\205\265\341\204\213\341\205\255\341\206\274_reselect(1:1)\341\204\214\341\205\252\341\204\221\341\205\255_by_histogram.ipynb"
#  rename "code/image/prep2_reselect(1:1)\341\204\214\341\205\252\341\204\221\341\205\255_by_histogram.ipynb" => code/image/prep3_create_square_image_by_histogram.ipynb (100%)
#  create mode 100644 "code/image/prep3_df\341\204\213\341\205\265\341\204\213\341\205\255\341\206\274_create_square_image_by_histogram.ipynb"
#  create mode 100644 "code/song/practice_modeling/VGG_Food(crop)_240527.ipynb\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253"
#  create mode 100644 code/song/practice_modeling/practice3_VGG_1_flower.ipynb
#  create mode 100644 code/song/practice_modeling/practice3_VGG_2_food.ipynb
#  create mode 100644 code/song/practice_modeling/practice4_food_classification.ipynb
# Enumerating objects: 21, done.
# Counting objects: 100% (21/21), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (14/14), done.
# Writing objects: 100% (14/14), 76.11 KiB | 1.09 MiB/s, done.
# Total 14 (delta 6), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (6/6), completed with 4 local objects.
# To https://github.com/dothouse/project3.git
#    703e6d4..52abf58  master -> master

# %%
# !git remote rm origin
