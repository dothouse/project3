# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/project3
# Out:
# /content/drive/MyDrive/project3

# %%
# !git config --global user.email 'dothouse@naver.com'
# !git config --global user.name 'dothouse'

# %%
# !git add .
# !git commit -m "day5(0524)_1 commit"
# !git push origin master
# Out:
# [master af13a68] day5(0524)_1 commit
#  9 files changed, 26 insertions(+), 133 deletions(-)
#  delete mode 100644 "code/chatbot/min/240521 \341\204\200\341\205\262\341\204\216\341\205\265\341\206\250\341\204\200\341\205\265\341\204\207\341\205\241\341\206\253 \341\204\216\341\205\242\341\206\272\341\204\207\341\205\251\341\206\272 \341\204\213\341\205\247\341\206\253\341\204\211\341\205\263\341\206\270 (1).ipynb"
#  create mode 100644 "code/image/KIM/KNN_food(\341\204\214\341\205\256\341\206\274\341\204\207\341\205\256\341\206\253\341\204\205\341\205\262)_240522.ipynb"
#  create mode 100644 code/image/KIM/ResNet_Flower_240524.ipynb
#  rewrite code/image/step0_data_prepration(upload_and_unzip).ipynb (98%)
#  rewrite code/image/step1_data_prepration(image_resize_and_tolist).ipynb (93%)
#  create mode 100644 code/image_function/manage_py_file.ipynb
#  rewrite project3)git.ipynb (91%)
# Enumerating objects: 30, done.
# Counting objects: 100% (30/30), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (17/17), done.
# Writing objects: 100% (17/17), 256.49 KiB | 3.61 MiB/s, done.
# Total 17 (delta 7), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (7/7), completed with 7 local objects.
# To https://github.com/dothouse/project3.git
#    005635e..af13a68  master -> master

# %%
# !git remote rm origin
