# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/project3
# Out:
# /content/drive/MyDrive/project3

# %%
# !git config --global user.email 'dothouse@naver.com'
# !git config --global user.name 'dothouse'

# %%
# !git add .
# !git commit -m "day(0528)_1 commit"
# !git push origin master
# Out:
# [master 703e6d4] day(0527)_1 commit
#  19 files changed, 6919 insertions(+), 4 deletions(-)
#  create mode 100644 "code/chatbot/min/240527 \341\204\214\341\205\242\341\204\205\341\205\255\341\204\206\341\205\247\341\206\274 \341\204\214\341\205\245\341\206\253\341\204\216\341\205\245\341\204\205\341\205\265.ipynb"
#  create mode 100644 code/chatbot/min/240527.txt
#  create mode 100644 "code/chatbot/min/\341\204\221\341\205\265\341\206\257\341\204\211\341\205\256\341\204\214\341\205\242\341\204\205\341\205\255 \341\204\211\341\205\242\341\206\274\341\204\211\341\205\245\341\206\274.csv"
#  create mode 100644 "code/chatbot/yoo/240527_\341\204\213\341\205\264\341\204\203\341\205\251\341\204\207\341\205\256\341\206\253\341\204\205\341\205\262_\341\204\213\341\205\263\341\206\267\341\204\211\341\205\265\341\206\250\341\204\214\341\205\242\341\204\205\341\205\255\341\204\207\341\205\256\341\206\253\341\204\205\341\205\262_2.ipynb"
#  create mode 100644 "code/chatbot/yoo/240527_\341\204\214\341\205\242\341\204\205\341\205\255\341\204\206\341\205\247\341\206\274\341\204\214\341\205\245\341\206\253\341\204\216\341\205\245\341\204\205\341\205\265_\341\204\221\341\205\265\341\206\257\341\204\211\341\205\256\341\204\214\341\205\242\341\204\205\341\205\255\341\204\214\341\205\242\341\204\205\341\205\255.ipynb"
#  create mode 100644 code/image/KIM/ResNet_crop_240527.ipynb
#  create mode 100644 code/image/KIM/Untitled0.ipynb
#  delete mode 100644 code/image/KIM/VGG_Food(all)_240523.ipynb
#  create mode 100644 code/image/KIM/VGG_Food(crop)_240527.ipynb
#  create mode 100644 code/image/KIM/image_preprocessing.ipynb
#  create mode 100644 code/image/Untitled
#  create mode 100644 code/image/check_crop_image.ipynb
#  create mode 100644 code/image/prep1_create_boxed_of_crop_image(copy_crop).ipynb
#  rewrite code/image/prep1_create_boxed_of_crop_image.ipynb (98%)
#  create mode 100644 "code/image/prep2_df\341\204\213\341\205\265\341\204\213\341\205\255\341\206\274_reselect(1:1)\341\204\214\341\205\252\341\204\221\341\205\255_by_histogram.ipynb"
#  rewrite "code/image/prep2_reselect(1:1)\341\204\214\341\205\252\341\204\221\341\205\255_by_histogram.ipynb" (99%)
#  rename "code/image/prep1-\341\204\206\341\205\265\341\204\211\341\205\241\341\204\213\341\205\255\341\206\274_create_boxed_of_crop_image.ipynb" => "code/image/\341\204\200\341\205\256\341\204\207\341\205\245\341\204\214\341\205\245\341\206\253/prep1-\341\204\206\341\205\265\341\204\211\341\205\241\341\204\213\341\205\255\341\206\274_create_boxed_of_crop_image.ipynb" (100%)
#  rename code/image/prep2_reselect(1:1)_by_histogram.ipynb => "code/image/\341\204\200\341\205\256\341\204\207\341\205\245\341\204\214\341\205\245\341\206\253/prep2-\341\204\206\341\205\265\341\204\211\341\205\241\341\204\213\341\205\255\341\206\274_reselect(1:1)_by_histogram.ipynb" (100%)
#  rewrite project3)git.ipynb (75%)
# Enumerating objects: 32, done.
# Counting objects: 100% (32/32), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (24/24), done.
# Writing objects: 100% (24/24), 333.74 KiB | 2.37 MiB/s, done.
# Total 24 (delta 11), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (11/11), completed with 5 local objects.
# To https://github.com/dothouse/project3.git
#    af600e6..703e6d4  master -> master

# %%
# !git remote rm origin
