# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/project3
# Out:
# /content/drive/MyDrive/project3

# %%
# !git config --global user.email 'dothouse@naver.com'
# !git config --global user.name 'dothouse'

# %%
# !git add .
# !git commit -m "day5(0524)_2 commit"
# !git push origin master
# Out:
# [master 0804821] day5(0524)_2 commit
#  5 files changed, 5 insertions(+), 4 deletions(-)
#  rewrite code/image/KIM/CNN_Food(all)_240522.ipynb (98%)
#  rewrite "code/image/KIM/KNN_food(\341\204\214\341\205\256\341\206\274\341\204\207\341\205\256\341\206\253\341\204\205\341\205\262)_240522.ipynb" (64%)
#  rewrite code/image/KIM/VGG_Food(all)_240523.ipynb (98%)
#  create mode 100644 code/song/Untitled0.ipynb
# Enumerating objects: 20, done.
# Counting objects: 100% (20/20), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (11/11), 9.67 KiB | 215.00 KiB/s, done.
# Total 11 (delta 8), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (8/8), completed with 8 local objects.
# To https://github.com/dothouse/project3.git
#    af13a68..0804821  master -> master

# %%
# !git remote rm origin
