# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/project3
# Out:
# /content/drive/MyDrive/project3

# %%
# !git config --global user.email 'dothouse@naver.com'
# !git config --global user.name 'dothouse'

# %%
# !git add .
# !git commit -m "day(0528)_1 commit"
# !git push origin master
# Out:
# [master cab4ff0] day(0528)_1 commit
#  3 files changed, 2 insertions(+), 2 deletions(-)
#  rename "code/image/\341\204\200\341\205\256\341\204\207\341\205\245\341\204\214\341\205\245\341\206\253/prep2-\341\204\206\341\205\265\341\204\211\341\205\241\341\204\213\341\205\255\341\206\274_reselect(1:1)_by_histogram.ipynb" => "code/image/\341\204\200\341\205\256\341\204\207\341\205\245\341\204\214\341\205\245\341\206\253/prep2-\341\204\206\341\205\265\341\204\211\341\205\241\341\204\213\341\205\255\341\206\274_reselect_by_histogram.ipynb" (100%)
#  rewrite project3)git.ipynb (84%)
# Enumerating objects: 17, done.
# Counting objects: 100% (17/17), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 3.24 KiB | 207.00 KiB/s, done.
# Total 9 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/dothouse/project3.git
#    52abf58..cab4ff0  master -> master

# %%
# !git remote rm origin
