# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/project3
# Out:
# /content/drive/MyDrive/project3

# %%
# !git config --global user.email 'dothouse@naver.com'
# !git config --global user.name 'dothouse'

# %%
# !git add .
# !git commit -m "day(0528)_4 commit"
# !git push origin master
# Out:
# [master fae7927] day(0528)_3 commit
#  4 files changed, 3 insertions(+), 3 deletions(-)
#  rename code/song/practice_preprocessing/{practice1_reselect(1:1)_by_histogram.ipynb => practice1_reselect_by_histogram.ipynb} (100%)
# Enumerating objects: 19, done.
# Counting objects: 100% (19/19), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (10/10), 1.66 KiB | 50.00 KiB/s, done.
# Total 10 (delta 7), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (7/7), completed with 7 local objects.
# To https://github.com/dothouse/project3.git
#    84d70ba..fae7927  master -> master

# %%
# !git remote rm origin
