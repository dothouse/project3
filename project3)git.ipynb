# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/project3
# Out:
# /content/drive/MyDrive/project3

# %%
# !git config --global user.email 'dothouse@naver.com'
# !git config --global user.name 'dothouse'

# %%
# !git add .
# !git commit -m "day3(0522)_1 commit"
# !git push origin master
# Out:
# [master 153d6be] day2(0521)_1 commit
#  6 files changed, 13934 insertions(+), 1 deletion(-)
#  create mode 100644 code/chatbot/song/1_recipe_cleaning.ipynb
#  create mode 100644 code/image/song/practice1_KNN_3(food_all).ipynb
#  create mode 100644 "code/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265/240430 10000recipe Preprocessing.ipynb"
#  create mode 100644 "code/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265/240502 10000recipe Crawling.ipynb"
#  create mode 100644 "code/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265 \341\204\214\341\205\245\341\206\253\341\204\216\341\205\245\341\204\205\341\205\265 \341\204\214\341\205\245\341\206\253.xlsx"
# Enumerating objects: 19, done.
# Counting objects: 100% (19/19), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (14/14), 165.09 KiB | 2.50 MiB/s, done.
# Total 14 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/dothouse/project3.git
#    35de0c5..153d6be  master -> master

# %%
# !git remote rm origin
