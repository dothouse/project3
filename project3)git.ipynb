# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/project3
# Out:
# /content/drive/MyDrive/project3

# %%
# !git config --global user.email 'dothouse@naver.com'
# !git config --global user.name 'dothouse'

# %%
# !git add .
# !git commit -m "day3(0522)_1 commit"
# !git push origin master
# Out:
# [master 84e86ca] day3(0522)_1 commit
#  38 files changed, 35822 insertions(+), 4 deletions(-)
#  create mode 100644 code/chatbot/min/10000recipe Preprocessing.csv
#  create mode 100644 code/chatbot/min/240522 10000recipe Preprocessing.ipynb
#  create mode 100644 "code/chatbot/min/240522 \341\204\213\341\205\262\341\204\211\341\205\241\341\204\203\341\205\251 \341\204\221\341\205\247\341\206\274\341\204\200\341\205\241.ipynb"
#  create mode 100644 code/chatbot/min/240522.txt
#  create mode 100644 "code/chatbot/min/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265/10000recipe Preprocessing.csv"
#  rename "code/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265/240430 10000recipe Preprocessing.ipynb" => "code/chatbot/min/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265/240430 10000recipe Preprocessing.ipynb" (100%)
#  rename "code/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265/240502 10000recipe Crawling.ipynb" => "code/chatbot/min/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265/240502 10000recipe Crawling.ipynb" (100%)
#  rename "code/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265 \341\204\214\341\205\245\341\206\253\341\204\216\341\205\245\341\204\205\341\205\265 \341\204\214\341\205\245\341\206\253.xlsx" => "code/chatbot/min/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265/\341\204\206\341\205\241\341\206\253\341\204\200\341\205\242\341\204\213\341\205\264\341\204\205\341\205\246\341\204\211\341\205\265\341\204\221\341\205\265 \341\204\214\341\205\245\341\206\253\341\204\216\341\205\245\341\204\205\341\205\265 \341\204\214\341\205\245\341\206\253.xlsx" (100%)
#  delete mode 100644 code/chatbot/song/1_recipe_cleaning.ipynb
#  create mode 100644 code/chatbot/yoo/240521.ipynb
#  create mode 100644 code/chatbot/yoo/240521_recipydata.ipynb
#  create mode 100644 code/image/KIM/CNN_Flower_240522.ipynb
#  create mode 100644 code/image/KIM/CNN_Food(all)_240522.ipynb
#  create mode 100644 "code/image/KIM/CNN_Food_\341\204\202\341\205\241\341\204\206\341\205\256\341\206\257_240522.ipynb"
#  create mode 100644 code/image/KIM/KNN_Flower_240522.ipynb
#  create mode 100644 code/image/KIM/KNN_food_240522.ipynb
#  create mode 100644 "code/image/KIM/KNN_food_\341\204\202\341\205\241\341\204\206\341\205\256\341\206\257_240522.ipynb"
#  rewrite code/image/KIM/Untitled0.ipynb (100%)
#  delete mode 100644 code/image/song/practice1_KNN_3(food_all).ipynb
#  create mode 100644 code/image/step0_data_prepration(upload_and_unzip).ipynb
#  create mode 100644 code/image/step1_data_prepration(image_resize_and_tolist).ipynb
#  create mode 100644 code/image_function/__pycache__/image_load.cpython-310.pyc
#  create mode 100644 code/image_function/__pycache__/vram_reset.cpython-310.pyc
#  create mode 100644 code/image_function/image_load.py
#  create mode 100644 code/image_function/vram_reset.py
#  create mode 100644 code/song/chat/step1_recipe_crawling.ipynb
#  create mode 100644 code/song/chat/step2_recipe_pre.ipynb
#  create mode 100644 code/song/chat/stetp3_rulebase_chatbot.ipynb
#  rename code/{image => }/song/practice1_KNN_1(flower).ipynb (100%)
#  rename code/{image => }/song/practice1_KNN_2(food_5).ipynb (100%)
#  create mode 100644 code/song/practice1_KNN_3(food_5_1000).ipynb
#  create mode 100644 code/song/practice1_KNN_3(food_all).ipynb
#  create mode 100644 code/song/practice1_KNN_3(food_all_100).ipynb
#  create mode 100644 code/song/practice1_KNN_3(food_all_cv2).ipynb
#  create mode 100644 code/song/practice2_CNN_1(Mninst).ipynb
#  create mode 100644 "code/song/practice2_CNN_2(food_\341\204\200\341\205\256\341\204\213\341\205\265).ipynb"
#  create mode 100644 "code/song/practice2_CNN_3(food_\341\204\200\341\205\256\341\204\213\341\205\265).ipynb"
#  rewrite project3)git.ipynb (94%)
# Enumerating objects: 55, done.
# Counting objects: 100% (55/55), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (48/48), done.
# Writing objects: 100% (48/48), 1.60 MiB | 1.67 MiB/s, done.
# Total 48 (delta 10), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (10/10), completed with 2 local objects.
# To https://github.com/dothouse/project3.git
#    153d6be..84e86ca  master -> master

# %%
# !git remote rm origin
